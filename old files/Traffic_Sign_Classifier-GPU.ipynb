# %% [markdown]
# # Self-Driving Car Engineer Nanodegree
#
# ## Deep Learning
#
# ## Project: Build a Traffic Sign Recognition Classifier

# %% [markdown]
# ---
# ## Step 0: Load The Data

# %%
import time
import pickle
import numpy as np
import tensorflow as tf
import csv
import cv2
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle
from keras.optimizers import Adam, SGD
from keras.layers import Input, Flatten, Dense, Conv2D, Add, Lambda, Cropping2D, MaxPooling2D
from keras.layers import BatchNormalization, Activation, Dropout, Concatenate
from keras.models import Model

import matplotlib.pyplot as plt
# Visualizations will be shown in the notebook.
# %matplotlib inline

ADAPT_LEARNING_RATE = False
DISABLE_PRINTS = False
EVALUATE_BATCH_TRAINING = False
AUGMENT_DATA = True
TRAIN_MODEL = True
GRAY_SCALE = False
LEARNING_CURVE = False # If False trains for all the training set

# Load pickled data
training_file = './traffic-signs-data/train.p'

validation_file= './traffic-signs-data/valid.p'
testing_file = './traffic-signs-data/test.p'

train_dict = pickle.load(open(training_file, mode='rb') )
valid_dict = pickle.load(open(validation_file, mode='rb'))
test_dict  = pickle.load(open(testing_file, mode='rb'))

coords_train, X_train, sizes_train, y_train = train_dict['coords'], train_dict['features'], train_dict['sizes'], train_dict['labels']

X_valid, y_valid = valid_dict['features'], valid_dict['labels']
X_test, y_test = test_dict['features'], test_dict['labels']
# Out:
# Using TensorFlow backend.

# %%
from cv2 import createCLAHE

def isGrayScale(image):
    if image.shape[-1] == 3 and len(image.shape) == 3:
        return False
    else:
        return True
    
def histogram_equalize_image(image, gridSize = (4, 4)):
    clahe = createCLAHE(tileGridSize=gridSize)
    if isGrayScale(image): 
        image = clahe.apply(image)            
        return image
    else:
        img_YCrCb = cv2.cvtColor(image, cv2.COLOR_RGB2YCrCb)            
        img_YCrCb[...,0] = clahe.apply(img_YCrCb[...,0])            
        image = cv2.cvtColor(img_YCrCb, cv2.COLOR_YCrCb2RGB)
        return image

def normalize_image(image):
    # pixels after normalization are in range [-0.5, +0.5]
    return (image - np.min(image))/(np.max(image)-np.min(image)) - 0.5

def preprocess_image(image, grayscale = GRAY_SCALE):  
    if grayscale:
        image = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)       
    return normalize_image(histogram_equalize_image(image))

def preprocess_data(X_data):
    return np.array([preprocess_image(image) for image in X_data]).reshape(X_data.shape[0], 32,32,-1)


def augment_data(X_data, enable = False):
    return np.array([random_transform_image(image, enable) for image in X_data]).reshape(X_data.shape[0], 32,32,-1)

# %%
def list_images(images, xaxis = "", yaxis ="", cmap=None, ncols = 10, title = ''):
    """
    Display a list of images in a single figure with matplotlib.
        Parameters:
            images: An np.array compatible with plt.imshow.
            yaxis (Default = " "): A string to be used as a label for each image.
            cmap (Default = None): Used to display gray images.
    """
    plt.figure(figsize=(10, 10))    
    n_images = len(images)
    nrows = np.ceil(n_images/ncols) 

    for i in range(n_images):
        plt.subplot(nrows, ncols, i+1)
        #Use gray scale color map if there is only one channel
        cmap = 'gray' if images[i].shape[-1] != 3 else cmap
        plt.imshow(np.squeeze(images[i]), cmap = cmap)
        plt.xlabel(xaxis)
        plt.ylabel(yaxis)
        plt.xticks([])
        plt.yticks([])    
    plt.tight_layout(pad=0, h_pad=0, w_pad=0)    
    plt.title(title, loc = 'center', fontsize=16)        
    plt.show()        

# 60
def rotate_image(image, angle_range = 30):
    rows,cols,ch = image.shape
    random_angle = np.random.uniform(angle_range)-angle_range/2
    rot_mat = cv2.getRotationMatrix2D((cols/2,rows/2), random_angle, scale = 1)
    return cv2.warpAffine(image,rot_mat,(cols,rows))

# 20
def translate_image(image, trans_range = 5):
    rows,cols,ch = image.shape
    tr_x = trans_range*np.random.uniform()-trans_range/2
    tr_y = trans_range*np.random.uniform()-trans_range/2
    Trans_M = np.float32([[1,0,tr_x],[0,1,tr_y]])
    return cv2.warpAffine(image,Trans_M,(cols,rows))

def shear_image(image, shear_range = 5):
    rows,cols,ch = image.shape
    pts1 = np.float32([[5,5],[20,5],[5,20]])
    pt1 = 5+shear_range*np.random.uniform()-shear_range/2
    pt2 = 20+shear_range*np.random.uniform()-shear_range/2
    pts2 = np.float32([[pt1,5],[pt2,pt1],[5,pt2]])
    shear_M = cv2.getAffineTransform(pts1,pts2)
    return cv2.warpAffine(image,shear_M,(cols,rows))

# 0.5, 1.5
def change_brightness_image(image, brightness_range = 1.5):  
    random_bright = 1 + brightness_range*np.random.uniform() - brightness_range/2 
    if not isGrayScale(image):
        image = cv2.cvtColor(image,cv2.COLOR_RGB2YCrCb).astype('float64')
        image[:,:,0] = np.round(image[:,:,0]*random_bright)
        image[:,:,0][image[:,:,0] > 255]  = 255
        image = image.astype('uint8')
        image = cv2.cvtColor(image,cv2.COLOR_YCrCb2RGB)
        return image
    else:    
        image = image.astype('float64')
        image = np.round(image*random_bright)
        image[image > 255]  = 255
        image = image.astype('uint8')
        return image
        
        return image

def motion_blur_image(image):
    size = 3
    # generating the kernel
    kernel_motion_blur = np.zeros((size, size))
    kernel_motion_blur[int((size-1)/2), :] = np.ones(size)
    kernel_motion_blur = kernel_motion_blur / size
    return cv2.filter2D(image, -1, kernel_motion_blur)
    
def random_transform_image(image, enable = False):    
    id_transformation = np.random.randint(2)
    if not enable or id_transformation == 0:
        return image
    
    rotation_flag = np.random.randint(2)
    if rotation_flag == 1:
        image = rotate_image(image)
        
    translation_flag = np.random.randint(2)
    if translation_flag == 1:
        image = translate_image(image)
    
    shear_flag = np.random.randint(2)
    if shear_flag == 1:
        image = shear_image(image)

    brightness_flag = np.random.randint(2)
    if brightness_flag == 1:
        image = change_brightness_image(image)

    return image

# %%
def evaluate(X_data, y_data):
    # ********************** hyper-parameters ************************
    batch_size  = 1024 # non consequential parameter for eval
    N_CLASSES = 43
    # ********************** **********************************************
    
    num_examples    = X_data.shape[0]
    sess = tf.get_default_session()
    
    
    total_TP = np.zeros(N_CLASSES, dtype=np.float32)
    total_FP = np.zeros(N_CLASSES, dtype=np.float32)
    total_FN = np.zeros(N_CLASSES, dtype=np.float32)    
    total_correct_predictions = 0
    total_loss = 0
    
    t1 = time.time()
    for offset in range(0, num_examples, batch_size):
        end = np.minimum(offset + batch_size, num_examples)
        batch_x, batch_y = X_data[offset:end], y_data[offset:end]
        batch_x_predicted_labels, batch_loss = sess.run([prediction, loss_operation], 
                                              feed_dict={x: batch_x, 
                                                           y: batch_y, 
                                                           BN: False, 
                                                           keep_prob_fc: np.ones(2).reshape([2, 1]),
                                                           beta_regularization: np.zeros(2).reshape([2, 1])})
        
        
        actuals      = sess.run(tf.one_hot(batch_y, N_CLASSES))
        predictions  = sess.run(tf.one_hot(batch_x_predicted_labels, N_CLASSES))        
        
        total_TP += np.count_nonzero(predictions * actuals, axis=0)
        total_FP += np.count_nonzero(predictions * (actuals - 1), axis=0)
        total_FN += np.count_nonzero((predictions - 1) * actuals, axis=0)     
       
        
        total_correct_predictions += np.sum(np.equal(batch_x_predicted_labels, batch_y))
        total_loss                += (batch_loss * batch_x.shape[0])
    
    
    accuracy  = total_correct_predictions/num_examples
    loss      = total_loss/num_examples
    precision = total_TP/(total_TP + total_FP + 1e-6)
    recall    = total_TP/(total_TP + total_FN + 1e-6)
    F1score   = 2 * precision * recall / (precision + recall + 1e-6)
    t2 = time.time()
    print("time take for samples = {} is {:.4f}".format(num_examples, t2-t1))
    return {"loss": loss,
            "accuracy": accuracy,
            "precision": precision,
            "recall": recall,
            "F1score": F1score
           }



def train_model(X_train, y_train, X_valid, y_valid, hyperPar_dict):        
    # ********************** read hyper-parameters ************************
    epochs              = hyperPar_dict['epochs']
    batch_size          = hyperPar_dict['batch_size']
    learning_rate       = hyperPar_dict['learning_rate']
    batch_norm          = hyperPar_dict['batch_norm']
    keep_probability_fc = hyperPar_dict['keep_prob_fc']
    beta_regularization_parameters = hyperPar_dict['beta_regularization']
    # ********************** ********************* ************************
    
    N_CLASSES = 43
    training_loss       = np.zeros(epochs)
    training_accuracy   = np.zeros(epochs)
    training_precision  = np.zeros([N_CLASSES, epochs])
    training_recall     = np.zeros([N_CLASSES, epochs])
    training_F1score    = np.zeros([N_CLASSES, epochs])
    
    
    validation_loss      = np.zeros(epochs)
    validation_accuracy  = np.zeros(epochs)    
    validation_precision = np.zeros([N_CLASSES, epochs])
    validation_recall    = np.zeros([N_CLASSES, epochs])
    validation_F1score   = np.zeros([N_CLASSES, epochs])
    
    
    with tf.Session() as sess:               
        sess.run(tf.global_variables_initializer())
        max_validation_accuracy = 0.95
        max_id = -1
        for i in range(epochs): 
            t1 = time.time()
            if (i+1)%20 == 0 and ADAPT_LEARNING_RATE:
                learning_rate *= 0.3
            
            X_train, y_train = shuffle(X_train, y_train)
            for offset in range(0, X_train.shape[0], batch_size):
                end = np.minimum(offset + batch_size, X_train.shape[0])
                batch_x, batch_y = preprocess_data(augment_data(X_train[offset:end], enable = AUGMENT_DATA)), y_train[offset:end]
                sess.run(training_operation, feed_dict={x: batch_x, 
                                                        y: batch_y, 
                                                        BN: batch_norm, 
                                                        learn_rate: learning_rate,
                                                        keep_prob_fc: keep_probability_fc,
                                                        beta_regularization: beta_regularization_parameters})

            t2 = time.time()            
            # **************** update results after an epoch ************************
            if EVALUATE_BATCH_TRAINING:
                training_results_dict   = evaluate(preprocess_data(X_train[offset:end]), y_train[offset:end])
            else:
                training_results_dict   = evaluate(preprocess_data(X_train), y_train)

            validation_results_dict = evaluate(X_valid, y_valid)
            t3 = time.time()

            training_accuracy[i]    = training_results_dict['accuracy']
            training_loss[i]        = training_results_dict['loss']        
            training_precision[:,i]   = training_results_dict['precision']
            training_recall[:,i]      = training_results_dict['recall']
            training_F1score[:,i]     = training_results_dict['F1score']
            
            
            validation_accuracy[i]    = validation_results_dict['accuracy']
            validation_loss[i]        = validation_results_dict['loss']        
            validation_precision[:,i]   = validation_results_dict['precision']
            validation_recall[:,i]      = validation_results_dict['recall']
            validation_F1score[:,i]     = validation_results_dict['F1score']

            if validation_accuracy[i]  > max_validation_accuracy:
                max_validation_accuracy = validation_accuracy[i]
                max_id                  = i
                saver.save(sess, './OptimizedModel')
                
            # *********************************************************************** 
            if not DISABLE_PRINTS:            
                print("EPOCH {} ...".format(i+1))
                print("Time taken for training = {:.2f} and total evaluation = {:.2f} ".format((t2-t1), (t3-t2)))
                #print("Learning rate = {:.3f}".format(learning_rate*1000))
                #print("")
                print("Training   [Accuracy, Loss] = [{:.3f}, {:.3f}]".format(training_accuracy[i], training_loss[i]))
                print("Validation [Accuracy, Loss] = [{:.3f}, {:.3f}]".format(validation_accuracy[i], validation_loss[i]))
                print("Best Validation Accuracy so far is {:.3f} for EPOCH {:.3f}".format(max_validation_accuracy, max_id))
                print()
    
    results_dict = {"training_accuracy": training_accuracy,                    
                    "training_loss": training_loss,
                    "training_precision": training_precision,
                    "training_recall": training_recall,
                    "training_F1score": training_F1score,
                    "validation_accuracy": validation_accuracy,                    
                    "validation_loss": validation_loss,
                    "validation_precision": validation_precision,
                    "validation_recall": validation_recall,
                    "validation_F1score": validation_F1score
                   }
    return results_dict


def learning_curve(X_train, y_train, X_valid, y_valid, hyperPar_dict, step_size = 2048):
    training_accuracy_list      = []
    training_loss_list          = []
    validation_accuracy_list    = []    
    validation_loss_list        = []
    
    step_size = np.minimum(step_size, X_train.shape[0])
    
    
    for m_train in range(step_size, X_train.shape[0]+1, step_size):            
        m_valid = int(np.minimum(np.round(m_train*.15), X_valid.shape[0]))
        print("Training using {training_samples} training samples and {valid_samples} validation samples"
              .format(training_samples = m_train, valid_samples = m_valid))
        print()

        X_train, y_train = shuffle(X_train, y_train)
        X_valid, y_valid = shuffle(X_valid, y_valid)        
        #*******************************************
        # Train the model for m samples
        # ******************************************
        results_dict_mSamples = train_model(X_train[0:m_train], y_train[0:m_train],
        X_valid[0:m_valid], y_valid[0:m_valid], 
        hyperPar_dict)            

        training_accuracy_list.append(results_dict_mSamples['training_accuracy'])
        training_loss_list.append(results_dict_mSamples['training_loss'])

        validation_accuracy_list.append(results_dict_mSamples['validation_accuracy'])
        validation_loss_list.append(results_dict_mSamples['validation_loss'])
        

    learning_curve_results = {
        "training_accuracy": np.array(training_accuracy_list),
        "training_loss": np.array(training_loss_list),
        "validation_accuracy": np.array(validation_accuracy_list),
        "validation_loss": np.array(validation_loss_list)
    }   
    

    return learning_curve_results


def display_stats(X_train, y_train, X_valid, y_valid):
    # Number of training examples
    n_train = X_train.shape[0]

    # Number of validation examples
    n_valid = X_valid.shape[0]

    # Number of testing examples.
    n_test = X_test.shape[0]

    # shape of an traffic sign image
    image_shape = np.array([X_train.shape[1], X_train.shape[2]])

    # How many unique classes/labels there are in the dataset.
    N_CLASSES = len(np.unique(y_train))

    # bin count of different classes
    n_train_images_in_a_Class = np.bincount(y_train)

    print("Number of training examples =", n_train)
    print("Number of validation examples =", n_valid)
    print("Number of testing examples =", n_test)
    print("Image data shape =", image_shape)
    print("Number of classes =", N_CLASSES)

    # Mapping ClassID to traffic sign names
    signs = []
    signnames = csv.reader(open('signnames.csv', 'r'), delimiter=',')
    next(signnames,None)
    for row in signnames:
        signs.append(row[1])
    

def display_samples(X_data, coords = None, sizes = None):
    # Display sample images
    disp_sample_idx  = np.random.randint(0, X_data.shape[0], 10)

    # display original samples
    print('original images')
    list_images(X_data[disp_sample_idx])

    print('boxed original images')
    list_images(get_boxed_images(data_set   = X_data[disp_sample_idx], coords = coords[disp_sample_idx], sizes = sizes[disp_sample_idx]))
    print('Cropped images')
    list_images(get_cropped_images(data_set = X_data[disp_sample_idx], coords = coords[disp_sample_idx], sizes = sizes[disp_sample_idx]))

    # display normalized samples
    print('normalized images')
    list_images(normalize_dataset(X_data[disp_sample_idx]))

    print('histogram equalized gray scale images')
    list_images(histogram_equalization(X_data[disp_sample_idx]))



def explore_data(X_train, y_train, X_valid, y_valid):
    # explore data set for random 1000 images
    sample_id  = np.random.randint(0, X_train.shape[0], 1000)
    # Mean and variance image of a data set
    X_explore_data = X_train[sample_id]

    mean_img = np.mean(X_explore_data, axis = 0).astype('uint8')
    std_img = np.std(X_explore_data, axis = 0).astype('uint8')
    list_images([mean_img, std_img])
    # Compute histogram of entropy
    # pixel_variance(data_set, equalize = False)
    variance_data = histogram_equalization(X_explore_data, equalize = False)
    plt.hist(variance_data)
    plt.show()

    # Histogram of train
    hist_y_train = np.bincount(y_train)
    hist_y_valid = np.bincount(y_valid)

    nhist_y_train = hist_y_train
    nhist_y_valid = hist_y_valid

    y_pos = np.arange(len(np.unique(y_train)))
    fig, ax = plt.subplots()
    ax.bar(y_pos, nhist_y_train, 0.35, align='center', alpha=0.5, color = 'b', label = 'train')
    #ax.bar(y_pos, nhist_y_valid, 0.8, align='center', alpha=0.5, color = 'g', label = 'valid')
    ax.set_ylabel('count of images in a class')
    ax.set_xlabel('class ID')
    legend = ax.legend(loc='upper center', shadow=True, fontsize='x-large')
    plt.show() 

    fig, ax = plt.subplots()
    #ax.bar(y_pos, nhist_y_train, 0.35, align='center', alpha=0.5, color = 'b', label = 'train')
    ax.bar(y_pos, nhist_y_valid, 0.8, align='center', alpha=0.5, color = 'g', label = 'valid')
    ax.set_ylabel('count of images in a class')
    ax.set_xlabel('class ID')
    legend = ax.legend(loc='upper center', shadow=True, fontsize='x-large')
    plt.show() 

    print("Distribution of different classes in training is \n", (hist_y_train))

# %%
# Read an image
idx = 820
print("histogram-rotate-translate-shear")
image1 = histogram_equalize_image(X_train[idx])
image2 = rotate_image(X_train[idx])
image3 = translate_image(X_train[idx])
image4 = shear_image(X_train[idx])
image5 = change_brightness_image(X_train[idx])

list_images(images = np.array([image1, image2, image3, image4, image5]), xaxis = "", yaxis ="", cmap=None, ncols = 5, title = '')
# Out:
# histogram-rotate-translate-shear

# %% [markdown]
# ---
#
# ## Step 1: Dataset Summary & Exploration
#
# The pickled data is a dictionary with 4 key/value pairs:
#
# - `'features'` is a 4D array containing raw pixel data of the traffic sign images, (num examples, width, height, channels).
# - `'labels'` is a 1D array containing the label/class id of the traffic sign. The file `signnames.csv` contains id -> name mappings for each id.
# - `'sizes'` is a list containing tuples, (width, height) representing the original width and height the image.
# - `'coords'` is a list containing tuples, (x1, y1, x2, y2) representing coordinates of a bounding box around the sign in the image. **THESE COORDINATES ASSUME THE ORIGINAL IMAGE. THE PICKLED DATA CONTAINS RESIZED VERSIONS (32 by 32) OF THESE IMAGES**

# %% [markdown]
# ----
#
# ## Step 2: Design and Test a Model Architecture
#
# There are various aspects to consider when thinking about this problem:
#
# - Neural network architecture (is the network over or underfitting?)
# - Play around preprocessing techniques (normalization, rgb to grayscale, etc)
# - Number of examples per label (some have more than others).
# - Generate fake data.
#
# Here is an example of a [published baseline model on this problem](http://yann.lecun.com/exdb/publis/pdf/sermanet-ijcnn-11.pdf). It's not required to be familiar with the approach used in the paper but, it's good practice to try to read papers like these.

# %% [markdown]
# ### Model Architecture

# %%
### Define your architecture here.
import tensorflow as tf
from tensorflow.contrib.layers import flatten, batch_norm

def maxpool2d(x, k=2):
    return tf.nn.max_pool(
        x,
        ksize=[1, k, k, 1],
        strides=[1, k, k, 1],
        padding='SAME')

def activation(x, func = 'relu', BN = False):
    if BN == True:
        if func == 'relu':
            return batch_norm(tf.nn.relu(x)) 
        elif func == 'elu':
            return batch_norm(tf.nn.elu(x))
        elif func == 'lrelu':
            return batch_norm(tf.nn.leaky_relu(x, alpha = 0.1))
        else:
            assert False, " unsupported activation function used"
    else:
        if func == 'relu':
            return tf.nn.relu(x)
        elif func == 'elu':
            return tf.nn.elu(x)
        elif func == 'lrelu':
            return tf.nn.leaky_relu(x, alpha = 0.1)
        else:
            assert False, " unsupported activation function used"
    

def conv2d(x, W, b, strides=1):
    return tf.nn.conv2d(x, W, strides=[1, strides, strides, 1], padding='VALID') + b
    

# tf.constant(value,dtype=None)    
def LeNet(x, batch_norm = False, keep_prob_fc = np.ones(2).reshape([2 , 1]),
         beta_regularization = np.zeros(2).reshape([2 , 1])):   
    
    BN_flag = batch_norm
    activation_func = 'relu'    

    if not GRAY_SCALE:
        # conv00: Input = 32x32X3. Output = 32x32x3.
        # General color map transformation
        wc00 = tf.get_variable("wc00", shape = [1, 1, 3, 3], initializer=tf.contrib.layers.xavier_initializer())
        bc00 = tf.Variable(tf.zeros(3))
        conv00 = conv2d(x, wc00, bc00)
        #layer00_out = activation(conv00, func = activation_func, BN = BN_flag)
        layer00_out = conv00

        # conv01: Input = 32x32X3. Output = 32x32x1.
        # General gray scale transformation
        wc01 = tf.get_variable("wc01", shape = [1, 1, 3, 1], initializer=tf.contrib.layers.xavier_initializer())
        bc01 = tf.Variable(tf.zeros(1))
        conv01 = conv2d(layer00_out, wc01, bc01)
        #layer01_out = activation(conv01, func = activation_func, BN = BN_flag)
        layer01_out = conv01
    else:
        layer01_out = x
        
    # conv1: Input = 32x32X1. Output = 28x28x6.
    # Weights = 5X5X1X6 = 150
    wc1 = tf.get_variable("wc1", shape = [5, 5, 1, 6], initializer=tf.contrib.layers.xavier_initializer())
    bc1 = tf.Variable(tf.zeros(6))
    conv1 = conv2d(layer01_out, wc1, bc1)
    #Pooling. Input = 28x28x6. Output = 14x14x6.
    maxp1 = maxpool2d(conv1, k=2)
    #Activation. Output = 14x14x6.
    layer1_out = activation(maxp1, func = activation_func, BN = BN_flag)

    
    # conv2: Input = 14x14X6. Output = 10x10x16.
    # Weights = 5X5X6X16 = 2.4k
    wc2 = tf.get_variable("wc2", shape = [5, 5, 6, 16], initializer=tf.contrib.layers.xavier_initializer())
    bc2 = tf.Variable(tf.zeros(16))
    conv2 = conv2d(layer1_out, wc2, bc2)
    #Pooling. Input = 10x10x16.. Output = 5x5x16..
    maxp2 = maxpool2d(conv2, k=2)
    #Activation. Output = 5x5x16.
    layer2_out = activation(maxp2, func = activation_func, BN = BN_flag)

    
    # Flatten. Input = 5x5x16. Output = 400
    fc3_inp = flatten(layer2_out)

    # Layer 3: Fully Connected. Input = 400. Output = 120.
    # Weights = 400*120 = 48k
    wfc3 = tf.get_variable("wfc3", shape = [400, 120], initializer=tf.contrib.layers.xavier_initializer())
    bfc3 = tf.Variable(tf.zeros(120))    
    # Sameer: change tf.add and tf.multiply
    fc3  = tf.add(tf.matmul(fc3_inp,wfc3),bfc3)
    # TODO: Activation.
    layer3_out = activation(fc3, func = activation_func, BN = BN_flag)
    layer3_out = tf.nn.dropout(layer3_out, keep_prob_fc[0,0])


    # Layer 4: Fully Connected. Input = 120. Output = 84.
    # Weights = 120*84 ~ 10k
    wfc4 = tf.get_variable("wfc4", shape = [120, 84], initializer=tf.contrib.layers.xavier_initializer())
    bfc4 = tf.Variable(tf.zeros(84))    
    fc4  = tf.add(tf.matmul(layer3_out, wfc4),bfc4)
    # TODO: Activation.
    layer4_out = activation(fc4, func = activation_func, BN = BN_flag)
    layer4_out = tf.nn.dropout(layer4_out, keep_prob_fc[1,0])
    

    # Layer 5: Fully Connected. Input = 84. Output = 43.
    # Weights = 84*43 ~ 3.6k
    # Biases = 43
    wfc5 = tf.get_variable("wfc5", shape = [84, 43], initializer=tf.contrib.layers.xavier_initializer())
    bfc5 = tf.Variable(tf.zeros(43))    
    fc5  = tf.add(tf.matmul(layer4_out, wfc5),bfc5)
    logits = fc5
   

    regularizers = beta_regularization[0,0] * tf.nn.l2_loss(wfc3) + beta_regularization[1,0]*tf.nn.l2_loss(wfc4)
    return logits, regularizers

# %% [markdown]
# ## Train, Validate and Test the Model

# %% [markdown]
# A validation set can be used to assess how well the model is performing. A low accuracy on the training and validation
# sets imply underfitting. A high accuracy on the training set but low accuracy on the validation set implies overfitting.

# %% [markdown]
# ### Training Pipeline

# %%
if GRAY_SCALE:
    n_channels = 1
else:
    n_channels = 3


#************************************************************************************
#                               INPUT-Variables
#************************************************************************************
x = tf.placeholder(tf.float32, (None, 32, 32, n_channels))
y = tf.placeholder(tf.int32, (None))
# Regularization
keep_prob_fc = tf.placeholder(tf.float32, shape = (2, 1))
beta_regularization = tf.placeholder(tf.float32, shape = (2, 1))
# Learning rate
learn_rate = tf.placeholder(tf.float32, (None))
# Batch norm
BN = tf.placeholder(tf.bool, (None))





N_CLASSES = 43
one_hot_y = tf.one_hot(y, N_CLASSES)


#************************************************************************************
#                               Choose the neural network model
#************************************************************************************
logits, regularizers = LeNet(x, batch_norm = BN, keep_prob_fc = keep_prob_fc, beta_regularization = beta_regularization)
saver = tf.train.Saver()
#************************************************************************************


#************************************************************************************
#               Define compute nodes of interest in a given graph
#************************************************************************************
cross_entropy  = tf.nn.softmax_cross_entropy_with_logits(labels=one_hot_y, logits=logits)
loss_operation = tf.reduce_mean(tf.reduce_mean(cross_entropy) + regularizers)

optimizer = tf.train.AdamOptimizer(learning_rate = learn_rate)
training_operation = optimizer.minimize(loss_operation)

prediction = tf.argmax(logits, 1)
correct_prediction = tf.equal(prediction, tf.argmax(one_hot_y, 1))
accuracy_operation = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))
# Out:
# WARNING:tensorflow:From <ipython-input-7-f5154cc61024>:39: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See @{tf.nn.softmax_cross_entropy_with_logits_v2}.

# %% [markdown]
# # Train the Model

# %%
#X_train = preprocess_data(train_dict['features'])
X_valid = preprocess_data(valid_dict['features'])
X_test  = preprocess_data(test_dict['features'])

if not LEARNING_CURVE:
    step_size = X_train.shape[0]

# ********************** Set hyper-parameters ************************
hyperPar_dict = {"epochs": 200,
"batch_size": 64,
"learning_rate": 2e-3,
"batch_norm": True,
"keep_prob_fc": np.array([0.55, 0.55]).reshape([2, 1]),
"beta_regularization": np.array([0, 0]).reshape([2, 1])}
# ********************** ********************* ************************
    
learning_curve_results = learning_curve(X_train, y_train, X_valid, y_valid, hyperPar_dict, step_size)

training_accuracy_vs_m = learning_curve_results['training_accuracy'][:,-1]
training_loss_vs_m = learning_curve_results ['training_loss'][:,-1]
validation_accuracy_vs_m = learning_curve_results['validation_accuracy'][:,-1]
validation_loss_vs_m = learning_curve_results['validation_loss'][:,-1]
# Out:
# Training using 34799 training samples and 4410 validation samples
#
# time take for samples = 34799 is 11.0228
# time take for samples = 4410 is 1.3597
# EPOCH 1 ...
# Time taken for training = 26.03 and total evaluation = 16.39
# Training   [Accuracy, Loss] = [0.904, 0.356]
# Validation [Accuracy, Loss] = [0.861, 0.445]
# Best Validation Accuracy so far is 0.950 for EPOCH -1.000
#
# time take for samples = 34799 is 10.8537
# time take for samples = 4410 is 1.4355
# EPOCH 2 ...
# Time taken for training = 28.79 and total evaluation = 15.73
# Training   [Accuracy, Loss] = [0.945, 0.168]
# Validation [Accuracy, Loss] = [0.925, 0.229]
# Best Validation Accuracy so far is 0.950 for EPOCH -1.000
#
# time take for samples = 34799 is 13.3825
# time take for samples = 4410 is 1.5230
# EPOCH 3 ...
# Time taken for training = 32.08 and total evaluation = 21.10
# Training   [Accuracy, Loss] = [0.965, 0.122]
# Validation [Accuracy, Loss] = [0.942, 0.166]
# Best Validation Accuracy so far is 0.950 for EPOCH -1.000
#
# time take for samples = 34799 is 16.1418
# time take for samples = 4410 is 1.6441
# EPOCH 4 ...
# Time taken for training = 35.92 and total evaluation = 21.71
# Training   [Accuracy, Loss] = [0.980, 0.084]
# Validation [Accuracy, Loss] = [0.955, 0.138]
# Best Validation Accuracy so far is 0.955 for EPOCH 3.000
#
# time take for samples = 34799 is 12.0512
# time take for samples = 4410 is 1.6818
# EPOCH 5 ...
# Time taken for training = 32.96 and total evaluation = 17.30
# Training   [Accuracy, Loss] = [0.984, 0.069]
# Validation [Accuracy, Loss] = [0.956, 0.139]
# Best Validation Accuracy so far is 0.956 for EPOCH 4.000
#
# time take for samples = 34799 is 12.4515
# time take for samples = 4410 is 1.7116
# EPOCH 6 ...
# Time taken for training = 35.41 and total evaluation = 17.59
# Training   [Accuracy, Loss] = [0.984, 0.060]
# Validation [Accuracy, Loss] = [0.961, 0.111]
# Best Validation Accuracy so far is 0.961 for EPOCH 5.000
#
# time take for samples = 34799 is 15.0366
# time take for samples = 4410 is 1.7644
# EPOCH 7 ...
# Time taken for training = 33.86 and total evaluation = 20.44
# Training   [Accuracy, Loss] = [0.988, 0.050]
# Validation [Accuracy, Loss] = [0.966, 0.103]
# Best Validation Accuracy so far is 0.966 for EPOCH 6.000
#
# time take for samples = 34799 is 15.5520
# time take for samples = 4410 is 1.8617
# EPOCH 8 ...
# Time taken for training = 31.65 and total evaluation = 21.74
# Training   [Accuracy, Loss] = [0.989, 0.044]
# Validation [Accuracy, Loss] = [0.969, 0.083]
# Best Validation Accuracy so far is 0.969 for EPOCH 7.000
#
# time take for samples = 34799 is 15.0944
# time take for samples = 4410 is 2.0601
# EPOCH 9 ...
# Time taken for training = 34.66 and total evaluation = 23.96
# Training   [Accuracy, Loss] = [0.991, 0.036]
# Validation [Accuracy, Loss] = [0.972, 0.081]
# Best Validation Accuracy so far is 0.972 for EPOCH 8.000
#
# time take for samples = 34799 is 15.8504
# time take for samples = 4410 is 2.5385
# EPOCH 10 ...
# Time taken for training = 33.43 and total evaluation = 22.97
# Training   [Accuracy, Loss] = [0.993, 0.029]
# Validation [Accuracy, Loss] = [0.977, 0.068]
# Best Validation Accuracy so far is 0.977 for EPOCH 9.000
#
# time take for samples = 34799 is 15.5969
# time take for samples = 4410 is 2.1052
# EPOCH 11 ...
# Time taken for training = 34.69 and total evaluation = 21.71
# Training   [Accuracy, Loss] = [0.993, 0.030]
# Validation [Accuracy, Loss] = [0.976, 0.069]
# Best Validation Accuracy so far is 0.977 for EPOCH 9.000
#
# time take for samples = 34799 is 16.9651
# time take for samples = 4410 is 2.1608
# EPOCH 12 ...
# Time taken for training = 31.26 and total evaluation = 22.78
# Training   [Accuracy, Loss] = [0.990, 0.033]
# Validation [Accuracy, Loss] = [0.974, 0.081]
# Best Validation Accuracy so far is 0.977 for EPOCH 9.000
#
# time take for samples = 34799 is 18.3760
# time take for samples = 4410 is 2.2374
# EPOCH 13 ...
# Time taken for training = 33.26 and total evaluation = 27.44
# Training   [Accuracy, Loss] = [0.993, 0.030]
# Validation [Accuracy, Loss] = [0.977, 0.081]
# Best Validation Accuracy so far is 0.977 for EPOCH 12.000
#
# time take for samples = 34799 is 17.0143
# time take for samples = 4410 is 2.3487
# EPOCH 14 ...
# Time taken for training = 30.46 and total evaluation = 23.00
# Training   [Accuracy, Loss] = [0.993, 0.028]
# Validation [Accuracy, Loss] = [0.976, 0.070]
# Best Validation Accuracy so far is 0.977 for EPOCH 12.000
#
# time take for samples = 34799 is 17.5786
# time take for samples = 4410 is 2.4662
# EPOCH 15 ...
# Time taken for training = 29.52 and total evaluation = 23.66
# Training   [Accuracy, Loss] = [0.994, 0.021]
# Validation [Accuracy, Loss] = [0.975, 0.069]
# Best Validation Accuracy so far is 0.977 for EPOCH 12.000
#
# time take for samples = 34799 is 17.9398
# time take for samples = 4410 is 2.5205
# EPOCH 16 ...
# Time taken for training = 29.80 and total evaluation = 24.20
# Training   [Accuracy, Loss] = [0.995, 0.021]
# Validation [Accuracy, Loss] = [0.978, 0.068]
# Best Validation Accuracy so far is 0.978 for EPOCH 15.000
#
# time take for samples = 34799 is 18.6698
# time take for samples = 4410 is 2.6098
# EPOCH 17 ...
# Time taken for training = 29.87 and total evaluation = 24.92
# Training   [Accuracy, Loss] = [0.994, 0.023]
# Validation [Accuracy, Loss] = [0.977, 0.068]
# Best Validation Accuracy so far is 0.978 for EPOCH 15.000
#
# time take for samples = 34799 is 19.0511
# time take for samples = 4410 is 2.6723
# EPOCH 18 ...
# Time taken for training = 32.47 and total evaluation = 25.63
# Training   [Accuracy, Loss] = [0.996, 0.019]
# Validation [Accuracy, Loss] = [0.981, 0.063]
# Best Validation Accuracy so far is 0.981 for EPOCH 17.000
#
# time take for samples = 34799 is 19.7262
# time take for samples = 4410 is 2.7918
# EPOCH 19 ...
# Time taken for training = 30.96 and total evaluation = 26.12
# Training   [Accuracy, Loss] = [0.994, 0.021]
# Validation [Accuracy, Loss] = [0.975, 0.070]
# Best Validation Accuracy so far is 0.981 for EPOCH 17.000
#
# time take for samples = 34799 is 20.0472
# time take for samples = 4410 is 2.8599
# EPOCH 20 ...
# Time taken for training = 29.47 and total evaluation = 26.51
# Training   [Accuracy, Loss] = [0.996, 0.020]
# Validation [Accuracy, Loss] = [0.978, 0.071]
# Best Validation Accuracy so far is 0.981 for EPOCH 17.000
#
# time take for samples = 34799 is 20.7078
# time take for samples = 4410 is 2.8963
# EPOCH 21 ...
# Time taken for training = 29.74 and total evaluation = 27.35
# Training   [Accuracy, Loss] = [0.997, 0.016]
# Validation [Accuracy, Loss] = [0.983, 0.061]
# Best Validation Accuracy so far is 0.983 for EPOCH 20.000
#
# time take for samples = 34799 is 21.5206
# time take for samples = 4410 is 2.9653
# EPOCH 22 ...
# Time taken for training = 29.76 and total evaluation = 28.30
# Training   [Accuracy, Loss] = [0.996, 0.017]
# Validation [Accuracy, Loss] = [0.983, 0.054]
# Best Validation Accuracy so far is 0.983 for EPOCH 20.000
#
# time take for samples = 34799 is 21.5004
# time take for samples = 4410 is 3.0586
# EPOCH 23 ...
# Time taken for training = 29.96 and total evaluation = 28.34
# Training   [Accuracy, Loss] = [0.996, 0.016]
# Validation [Accuracy, Loss] = [0.982, 0.051]
# Best Validation Accuracy so far is 0.983 for EPOCH 20.000
#
# time take for samples = 34799 is 22.1529
# time take for samples = 4410 is 3.1365
# EPOCH 24 ...
# Time taken for training = 29.60 and total evaluation = 28.99
# Training   [Accuracy, Loss] = [0.997, 0.014]
# Validation [Accuracy, Loss] = [0.985, 0.053]
# Best Validation Accuracy so far is 0.985 for EPOCH 23.000
#
# time take for samples = 34799 is 22.5663
# time take for samples = 4410 is 3.2546
# EPOCH 25 ...
# Time taken for training = 30.17 and total evaluation = 29.56
# Training   [Accuracy, Loss] = [0.997, 0.014]
# Validation [Accuracy, Loss] = [0.983, 0.051]
# Best Validation Accuracy so far is 0.985 for EPOCH 23.000
#
# time take for samples = 34799 is 23.1753
# time take for samples = 4410 is 3.2633
# EPOCH 26 ...
# Time taken for training = 29.66 and total evaluation = 30.18
# Training   [Accuracy, Loss] = [0.995, 0.020]
# Validation [Accuracy, Loss] = [0.979, 0.065]
# Best Validation Accuracy so far is 0.985 for EPOCH 23.000
#
# time take for samples = 34799 is 23.5881
# time take for samples = 4410 is 3.3962
# EPOCH 27 ...
# Time taken for training = 30.01 and total evaluation = 30.68
# Training   [Accuracy, Loss] = [0.996, 0.016]
# Validation [Accuracy, Loss] = [0.983, 0.061]
# Best Validation Accuracy so far is 0.985 for EPOCH 23.000
# time take for samples = 34799 is 24.5575
# time take for samples = 4410 is 3.4533
# EPOCH 28 ...
# Time taken for training = 29.96 and total evaluation = 31.81
# Training   [Accuracy, Loss] = [0.996, 0.015]
# Validation [Accuracy, Loss] = [0.985, 0.050]
# Best Validation Accuracy so far is 0.985 for EPOCH 27.000
#
# time take for samples = 34799 is 24.9508
# time take for samples = 4410 is 3.5299
# EPOCH 29 ...
# Time taken for training = 29.97 and total evaluation = 32.29
# Training   [Accuracy, Loss] = [0.995, 0.018]
# Validation [Accuracy, Loss] = [0.974, 0.078]
# Best Validation Accuracy so far is 0.985 for EPOCH 27.000
#
# time take for samples = 34799 is 25.3746
# time take for samples = 4410 is 3.6393
# EPOCH 30 ...
# Time taken for training = 29.72 and total evaluation = 32.84
# Training   [Accuracy, Loss] = [0.996, 0.016]
# Validation [Accuracy, Loss] = [0.976, 0.069]
# Best Validation Accuracy so far is 0.985 for EPOCH 27.000
#
# time take for samples = 34799 is 26.0712
# time take for samples = 4410 is 3.7276
# EPOCH 31 ...
# Time taken for training = 29.79 and total evaluation = 33.55
# Training   [Accuracy, Loss] = [0.997, 0.013]
# Validation [Accuracy, Loss] = [0.983, 0.056]
# Best Validation Accuracy so far is 0.985 for EPOCH 27.000
#
# time take for samples = 34799 is 26.7825
# time take for samples = 4410 is 3.8586
# EPOCH 32 ...
# Time taken for training = 29.54 and total evaluation = 34.45
# Training   [Accuracy, Loss] = [0.997, 0.012]
# Validation [Accuracy, Loss] = [0.985, 0.053]
# Best Validation Accuracy so far is 0.985 for EPOCH 27.000
#
# time take for samples = 34799 is 27.3143
# time take for samples = 4410 is 3.9331
# EPOCH 33 ...
# Time taken for training = 29.72 and total evaluation = 35.03
# Training   [Accuracy, Loss] = [0.998, 0.011]
# Validation [Accuracy, Loss] = [0.986, 0.052]
# Best Validation Accuracy so far is 0.986 for EPOCH 32.000
#
# time take for samples = 34799 is 28.3192
# time take for samples = 4410 is 4.1776
# EPOCH 34 ...
# Time taken for training = 29.40 and total evaluation = 36.17
# Training   [Accuracy, Loss] = [0.997, 0.011]
# Validation [Accuracy, Loss] = [0.987, 0.048]
# Best Validation Accuracy so far is 0.987 for EPOCH 33.000
#
# time take for samples = 34799 is 28.8759
# time take for samples = 4410 is 4.1712
# EPOCH 35 ...
# Time taken for training = 29.37 and total evaluation = 36.75
# Training   [Accuracy, Loss] = [0.997, 0.013]
# Validation [Accuracy, Loss] = [0.984, 0.051]
# Best Validation Accuracy so far is 0.987 for EPOCH 33.000
#
# time take for samples = 34799 is 29.9509
# time take for samples = 4410 is 4.2617
# EPOCH 36 ...
# Time taken for training = 29.20 and total evaluation = 37.98
# Training   [Accuracy, Loss] = [0.997, 0.014]
# Validation [Accuracy, Loss] = [0.985, 0.053]
# Best Validation Accuracy so far is 0.987 for EPOCH 33.000
#
# time take for samples = 34799 is 30.2958
# time take for samples = 4410 is 4.3569
# EPOCH 37 ...
# Time taken for training = 29.54 and total evaluation = 38.63
# Training   [Accuracy, Loss] = [0.997, 0.011]
# Validation [Accuracy, Loss] = [0.983, 0.048]
# Best Validation Accuracy so far is 0.987 for EPOCH 33.000
#
# time take for samples = 34799 is 31.3454
# time take for samples = 4410 is 4.5060
# EPOCH 38 ...
# Time taken for training = 29.42 and total evaluation = 39.89
# Training   [Accuracy, Loss] = [0.996, 0.014]
# Validation [Accuracy, Loss] = [0.979, 0.055]
# Best Validation Accuracy so far is 0.987 for EPOCH 33.000
#
# time take for samples = 34799 is 31.8348
# time take for samples = 4410 is 4.5957
# EPOCH 39 ...
# Time taken for training = 29.12 and total evaluation = 40.23
# Training   [Accuracy, Loss] = [0.998, 0.009]
# Validation [Accuracy, Loss] = [0.984, 0.047]
# Best Validation Accuracy so far is 0.987 for EPOCH 33.000
#
# time take for samples = 34799 is 32.6055
# time take for samples = 4410 is 4.7455
# EPOCH 40 ...
# Time taken for training = 32.10 and total evaluation = 41.50
# Training   [Accuracy, Loss] = [0.997, 0.012]
# Validation [Accuracy, Loss] = [0.982, 0.053]
# Best Validation Accuracy so far is 0.987 for EPOCH 33.000
#
# time take for samples = 34799 is 33.3652
# time take for samples = 4410 is 4.7996
# EPOCH 41 ...
# Time taken for training = 29.50 and total evaluation = 42.14
# Training   [Accuracy, Loss] = [0.997, 0.010]
# Validation [Accuracy, Loss] = [0.985, 0.046]
# Best Validation Accuracy so far is 0.987 for EPOCH 33.000
#
# time take for samples = 34799 is 33.9381
# time take for samples = 4410 is 4.9388
# EPOCH 42 ...
# Time taken for training = 29.36 and total evaluation = 43.04
# Training   [Accuracy, Loss] = [0.997, 0.011]
# Validation [Accuracy, Loss] = [0.983, 0.054]
# Best Validation Accuracy so far is 0.987 for EPOCH 33.000
#
# time take for samples = 34799 is 34.8735
# time take for samples = 4410 is 5.0183
# EPOCH 43 ...
# Time taken for training = 29.77 and total evaluation = 43.83
# Training   [Accuracy, Loss] = [0.997, 0.012]
# Validation [Accuracy, Loss] = [0.980, 0.063]
# Best Validation Accuracy so far is 0.987 for EPOCH 33.000
#
# time take for samples = 34799 is 35.5145
# time take for samples = 4410 is 5.1297
# EPOCH 44 ...
# Time taken for training = 32.87 and total evaluation = 44.78
# Training   [Accuracy, Loss] = [0.998, 0.012]
# Validation [Accuracy, Loss] = [0.983, 0.058]
# Best Validation Accuracy so far is 0.987 for EPOCH 33.000
#
# time take for samples = 34799 is 36.4205
# time take for samples = 4410 is 5.2811
# EPOCH 45 ...
# Time taken for training = 29.83 and total evaluation = 46.00
# Training   [Accuracy, Loss] = [0.998, 0.011]
# Validation [Accuracy, Loss] = [0.987, 0.047]
# Best Validation Accuracy so far is 0.987 for EPOCH 44.000
#
# time take for samples = 34799 is 37.6224
# time take for samples = 4410 is 5.4214
# EPOCH 46 ...
# Time taken for training = 29.54 and total evaluation = 46.95
# Training   [Accuracy, Loss] = [0.998, 0.010]
# Validation [Accuracy, Loss] = [0.989, 0.043]
# Best Validation Accuracy so far is 0.989 for EPOCH 45.000
#
# time take for samples = 34799 is 38.1443
# time take for samples = 4410 is 5.4930
# EPOCH 47 ...
# Time taken for training = 30.04 and total evaluation = 47.93
# Training   [Accuracy, Loss] = [0.997, 0.012]
# Validation [Accuracy, Loss] = [0.987, 0.049]
# Best Validation Accuracy so far is 0.989 for EPOCH 45.000
#
# time take for samples = 34799 is 39.0954
# time take for samples = 4410 is 5.6155
# EPOCH 48 ...
# Time taken for training = 30.11 and total evaluation = 48.68
# Training   [Accuracy, Loss] = [0.998, 0.009]
# Validation [Accuracy, Loss] = [0.988, 0.041]
# Best Validation Accuracy so far is 0.989 for EPOCH 45.000
#
# time take for samples = 34799 is 39.9805
# time take for samples = 4410 is 5.6904
# EPOCH 49 ...
# Time taken for training = 29.84 and total evaluation = 49.62
# Training   [Accuracy, Loss] = [0.998, 0.009]
# Validation [Accuracy, Loss] = [0.988, 0.039]
# Best Validation Accuracy so far is 0.989 for EPOCH 45.000
#
# time take for samples = 34799 is 40.6434
# time take for samples = 4410 is 5.8650
# EPOCH 50 ...
# Time taken for training = 29.64 and total evaluation = 50.48
# Training   [Accuracy, Loss] = [0.998, 0.010]
# Validation [Accuracy, Loss] = [0.985, 0.049]
# Best Validation Accuracy so far is 0.989 for EPOCH 45.000
#
# time take for samples = 34799 is 41.2847
# time take for samples = 4410 is 5.9756
# EPOCH 51 ...
# Time taken for training = 29.85 and total evaluation = 51.44
# Training   [Accuracy, Loss] = [0.998, 0.008]
# Validation [Accuracy, Loss] = [0.984, 0.050]
# Best Validation Accuracy so far is 0.989 for EPOCH 45.000
#
# time take for samples = 34799 is 42.3836
# time take for samples = 4410 is 6.0920
# EPOCH 52 ...
# Time taken for training = 29.81 and total evaluation = 52.85
# Training   [Accuracy, Loss] = [0.998, 0.008]
# Validation [Accuracy, Loss] = [0.989, 0.040]
# Best Validation Accuracy so far is 0.989 for EPOCH 51.000
#
# time take for samples = 34799 is 43.0763
# time take for samples = 4410 is 6.1730
# EPOCH 53 ...
# Time taken for training = 29.93 and total evaluation = 53.33
# Training   [Accuracy, Loss] = [0.996, 0.013]
# Validation [Accuracy, Loss] = [0.979, 0.065]
# Best Validation Accuracy so far is 0.989 for EPOCH 51.000
#
# time take for samples = 34799 is 44.0323
# time take for samples = 4410 is 6.3114
# EPOCH 54 ...
# Time taken for training = 29.83 and total evaluation = 54.41
# Training   [Accuracy, Loss] = [0.998, 0.008]
# Validation [Accuracy, Loss] = [0.987, 0.044]
# Best Validation Accuracy so far is 0.989 for EPOCH 51.000
# time take for samples = 34799 is 44.8410
# time take for samples = 4410 is 6.5404
# EPOCH 55 ...
# Time taken for training = 29.99 and total evaluation = 55.76
# Training   [Accuracy, Loss] = [0.998, 0.009]
# Validation [Accuracy, Loss] = [0.984, 0.053]
# Best Validation Accuracy so far is 0.989 for EPOCH 51.000
#
# time take for samples = 34799 is 46.5831
# time take for samples = 4410 is 6.6168
# EPOCH 56 ...
# Time taken for training = 30.16 and total evaluation = 57.76
# Training   [Accuracy, Loss] = [0.997, 0.011]
# Validation [Accuracy, Loss] = [0.988, 0.042]
# Best Validation Accuracy so far is 0.989 for EPOCH 51.000
#
# time take for samples = 34799 is 46.7000
# time take for samples = 4410 is 6.7678
# EPOCH 57 ...
# Time taken for training = 30.50 and total evaluation = 57.98
# Training   [Accuracy, Loss] = [0.997, 0.011]
# Validation [Accuracy, Loss] = [0.983, 0.056]
# Best Validation Accuracy so far is 0.989 for EPOCH 51.000
#
# time take for samples = 34799 is 47.5758
# time take for samples = 4410 is 6.8701
# EPOCH 58 ...
# Time taken for training = 31.05 and total evaluation = 58.80
# Training   [Accuracy, Loss] = [0.998, 0.009]
# Validation [Accuracy, Loss] = [0.988, 0.043]
# Best Validation Accuracy so far is 0.989 for EPOCH 51.000
#
# time take for samples = 34799 is 48.4324
# time take for samples = 4410 is 6.9630
# EPOCH 59 ...
# Time taken for training = 30.47 and total evaluation = 59.71
# Training   [Accuracy, Loss] = [0.998, 0.010]
# Validation [Accuracy, Loss] = [0.988, 0.042]
# Best Validation Accuracy so far is 0.989 for EPOCH 51.000
#
# time take for samples = 34799 is 49.3534
# time take for samples = 4410 is 7.1215
# EPOCH 60 ...
# Time taken for training = 30.55 and total evaluation = 60.85
# Training   [Accuracy, Loss] = [0.997, 0.010]
# Validation [Accuracy, Loss] = [0.988, 0.041]
# Best Validation Accuracy so far is 0.989 for EPOCH 51.000
#
# time take for samples = 34799 is 50.0165
# time take for samples = 4410 is 7.2221
# EPOCH 61 ...
# Time taken for training = 30.68 and total evaluation = 61.52
# Training   [Accuracy, Loss] = [0.998, 0.009]
# Validation [Accuracy, Loss] = [0.985, 0.050]
# Best Validation Accuracy so far is 0.989 for EPOCH 51.000
#
# time take for samples = 34799 is 50.6121
# time take for samples = 4410 is 7.3492
# EPOCH 62 ...
# Time taken for training = 30.71 and total evaluation = 62.24
# Training   [Accuracy, Loss] = [0.997, 0.011]
# Validation [Accuracy, Loss] = [0.981, 0.053]
# Best Validation Accuracy so far is 0.989 for EPOCH 51.000
#
# time take for samples = 34799 is 51.7776
# time take for samples = 4410 is 7.5463
# EPOCH 63 ...
# Time taken for training = 30.22 and total evaluation = 63.87
# Training   [Accuracy, Loss] = [0.997, 0.010]
# Validation [Accuracy, Loss] = [0.987, 0.050]
# Best Validation Accuracy so far is 0.989 for EPOCH 51.000
#
# time take for samples = 34799 is 52.7649
# time take for samples = 4410 is 7.6756
# EPOCH 64 ...
# Time taken for training = 31.73 and total evaluation = 64.85
# Training   [Accuracy, Loss] = [0.998, 0.011]
# Validation [Accuracy, Loss] = [0.984, 0.051]
# Best Validation Accuracy so far is 0.989 for EPOCH 51.000
#
# time take for samples = 34799 is 53.4683
# time take for samples = 4410 is 7.8074
# EPOCH 65 ...
# Time taken for training = 30.99 and total evaluation = 65.68
# Training   [Accuracy, Loss] = [0.997, 0.014]
# Validation [Accuracy, Loss] = [0.986, 0.046]
# Best Validation Accuracy so far is 0.989 for EPOCH 51.000
#
# time take for samples = 34799 is 54.5440
# time take for samples = 4410 is 7.9208
# EPOCH 66 ...
# Time taken for training = 30.93 and total evaluation = 67.32
# Training   [Accuracy, Loss] = [0.998, 0.009]
# Validation [Accuracy, Loss] = [0.988, 0.042]
# Best Validation Accuracy so far is 0.989 for EPOCH 51.000
#
# time take for samples = 34799 is 55.4260
# time take for samples = 4410 is 8.0454
# EPOCH 67 ...
# Time taken for training = 31.29 and total evaluation = 68.52
# Training   [Accuracy, Loss] = [0.998, 0.007]
# Validation [Accuracy, Loss] = [0.987, 0.044]
# Best Validation Accuracy so far is 0.989 for EPOCH 51.000
#
# time take for samples = 34799 is 58.4753
# time take for samples = 4410 is 8.6410
# EPOCH 68 ...
# Time taken for training = 32.66 and total evaluation = 76.13
# Training   [Accuracy, Loss] = [0.998, 0.009]
# Validation [Accuracy, Loss] = [0.985, 0.051]
# Best Validation Accuracy so far is 0.989 for EPOCH 51.000
#
# time take for samples = 34799 is 58.4650
# time take for samples = 4410 is 8.4148
# EPOCH 69 ...
# Time taken for training = 33.59 and total evaluation = 72.39
# Training   [Accuracy, Loss] = [0.999, 0.007]
# Validation [Accuracy, Loss] = [0.982, 0.057]
# Best Validation Accuracy so far is 0.989 for EPOCH 51.000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-ddc5eb5176fe> in <module>()
#      15 # ********************** ********************* ************************
#      16
# ---> 17 learning_curve_results = learning_curve(X_train, y_train, X_valid, y_valid, hyperPar_dict, step_size)
#      18
#      19 training_accuracy_vs_m = learning_curve_results['training_accuracy'][:,-1]
#
# <ipython-input-4-1a726309f9da> in learning_curve(X_train, y_train, X_valid, y_valid, hyperPar_dict, step_size)
#     175         results_dict_mSamples = train_model(X_train[0:m_train], y_train[0:m_train],
#     176         X_valid[0:m_valid], y_valid[0:m_valid],
# --> 177         hyperPar_dict)
#     178
#     179         training_accuracy_list.append(results_dict_mSamples['training_accuracy'])
#
# <ipython-input-4-1a726309f9da> in train_model(X_train, y_train, X_valid, y_valid, hyperPar_dict)
#     105                 training_results_dict   = evaluate(preprocess_data(X_train[offset:end]), y_train[offset:end])
#     106             else:
# --> 107                 training_results_dict   = evaluate(preprocess_data(X_train), y_train)
#     108
#     109             validation_results_dict = evaluate(X_valid, y_valid)
#
# <ipython-input-4-1a726309f9da> in evaluate(X_data, y_data)
#      27
#      28
# ---> 29         actuals      = sess.run(tf.one_hot(batch_y, N_CLASSES))
#      30         predictions  = sess.run(tf.one_hot(batch_x_predicted_labels, N_CLASSES))
#      31
#
# ~/anaconda3/envs/carnd-term1/lib/python3.5/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     898     try:
#     899       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 900                          run_metadata_ptr)
#     901       if run_metadata:
#     902         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~/anaconda3/envs/carnd-term1/lib/python3.5/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1133     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1134       results = self._do_run(handle, final_targets, final_fetches,
# -> 1135                              feed_dict_tensor, options, run_metadata)
#    1136     else:
#    1137       results = []
#
# ~/anaconda3/envs/carnd-term1/lib/python3.5/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1314     if handle is None:
#    1315       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1316                            run_metadata)
#    1317     else:
#    1318       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# ~/anaconda3/envs/carnd-term1/lib/python3.5/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1320   def _do_call(self, fn, *args):
#    1321     try:
# -> 1322       return fn(*args)
#    1323     except errors.OpError as e:
#    1324       message = compat.as_text(e.message)
#
# ~/anaconda3/envs/carnd-term1/lib/python3.5/site-packages/tensorflow/python/client/session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1303     def _run_fn(feed_dict, fetch_list, target_list, options, run_metadata):
#    1304       # Ensure any changes to the graph are reflected in the runtime.
# -> 1305       self._extend_graph()
#    1306       return self._call_tf_sessionrun(
#    1307           options, feed_dict, fetch_list, target_list, run_metadata)
#
# ~/anaconda3/envs/carnd-term1/lib/python3.5/site-packages/tensorflow/python/client/session.py in _extend_graph(self)
#    1338     if self._created_with_new_api:
#    1339       with self._graph._lock:  # pylint: disable=protected-access
# -> 1340         tf_session.ExtendSession(self._session)
#    1341     else:
#    1342       # Ensure any changes to the graph are reflected in the runtime.
#
# KeyboardInterrupt:

# %%
with tf.Session() as sess:
    saver.restore(sess,  './OptimizedModel')
    train_results_dict   = evaluate(preprocess_data(X_train), y_train)
    print("Train Accuracy = {:.3f}".format(train_results_dict['accuracy']))
    print("Train Loss = {:.3f}".format(train_results_dict['loss']))
    
    valid_results_dict   = evaluate(X_valid, y_valid)
    print("Validation Accuracy = {:.3f}".format(valid_results_dict['accuracy']))
    print("Validation Loss = {:.3f}".format(valid_results_dict['loss']))
    
    test_results_dict   = evaluate(X_test, y_test)
    print("Test Accuracy = {:.3f}".format(test_results_dict['accuracy']))
    print("Test Loss = {:.3f}".format(test_results_dict['loss']))

# %%
print(np.argsort(train_results_dict['precision']))
print()
print(np.argsort(valid_results_dict['precision']))
print()
print(np.argsort(test_results_dict['precision']))

# %%
print(np.argsort(train_results_dict['recall']))
print()
print(np.argsort(valid_results_dict['recall']))
print()
print(np.argsort(test_results_dict['recall']))

# %%
print(np.argsort(train_results_dict['F1score']))
print()
print(np.argsort(valid_results_dict['F1score']))
print()
print(np.argsort(test_results_dict['F1score']))

# %%
training_accuracy_vs_iter = learning_curve_results['training_accuracy'][0,:]
training_loss_vs_iter = learning_curve_results['training_loss'][0,:]
validation_accuracy_vs_iter = learning_curve_results['validation_accuracy'][0,:]
validation_loss_vs_iter = learning_curve_results['validation_loss'][0,:]

# %%
# %matplotlib inline
num = 0
plt.figure()
for i in range(learning_curve_results['training_accuracy'].shape[0]):
    if i==num:
        training_loss_vs_iter = learning_curve_results['training_loss'][i,:]
        validation_loss_vs_iter = learning_curve_results['validation_loss'][i,:]    
        plt.plot(np.arange(1, len(training_loss_vs_iter)+1), training_loss_vs_iter, label = 'train')
        plt.plot(np.arange(1, len(validation_loss_vs_iter)+1), validation_loss_vs_iter, label = 'valid')

plt.xlabel('Epochs')
plt.ylabel('Loss')
legend = plt.legend(loc='best')
plt.grid(True)
plt.show()

# %matplotlib inline
plt.figure()
for i in range(learning_curve_results['training_accuracy'].shape[0]):
    if i==num:
        training_accuracy_vs_iter = learning_curve_results['training_accuracy'][i,:]
        validation_accuracy_vs_iter = learning_curve_results['validation_accuracy'][i,:]    
        plt.plot(np.arange(1, len(training_accuracy_vs_iter)+1), training_accuracy_vs_iter, label = 'train')
        plt.plot(np.arange(1, len(validation_accuracy_vs_iter)+1), validation_accuracy_vs_iter, label = 'valid')

plt.xlabel('Epochs')
plt.ylabel('accuracy')
legend = plt.legend(loc='best')
plt.grid(True)
plt.show()

# %%
# %matplotlib inline
plt.figure()
plt.plot(np.arange(1, len(training_accuracy_vs_iter)+1), training_accuracy_vs_iter, 'b', label = 'training accuracy')
plt.plot(np.arange(1, len(validation_accuracy_vs_iter)+1), validation_accuracy_vs_iter, 'r', label = 'validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
legend = plt.legend(loc='best')
plt.grid(True)
plt.show()

# %%
print(np.argmax(validation_accuracy_vs_iter))
print(np.max(validation_accuracy_vs_iter))
print(np.argmax(training_accuracy_vs_iter))
print(np.max(training_accuracy_vs_iter))
